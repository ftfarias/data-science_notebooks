# %%
import pandas as pd

# %%
data_raw = pd.read_csv("./matching_uniq.csv",sep='\t')

# %%
data_raw.describe()
# Out:
#              match_id          job_id   job_longitude    job_latitude  \
# count  4918723.000000  4918723.000000  4904198.000000  4904198.000000
# mean   2591385.521576   159686.901753      -46.636892      -23.564002
# std    1492279.234802    61905.140728        0.115123        0.093293
# min          1.000000      263.000000      -49.053699      -25.452600
# 25%    1300230.500000   122611.000000      -46.697498      -23.583099
# 50%    2597246.000000   179775.000000      -46.646198      -23.553699
# 75%    3883190.500000   206451.000000      -46.573898      -23.521601
# max    5172186.000000   240046.000000      -35.200100       -1.344450
#
#             job_cargo    candidate_id  job_salary_max  job_salary_min  \
# count  4918723.000000  4918723.000000  2064930.000000  2064930.000000
# mean        33.335403   261561.280065      923.837944     1262.052296
# std         31.936532   176574.878288      541.088381     1053.799580
# ...

# %%
print data_raw.shape
# Out:
# (4918723, 21)

# %%
print data_raw.head()
# Out:
#    match_id  job_id  job_longitude  job_latitude  job_cargo  candidate_id  \
# 0         1     263       -46.6259      -23.4974          2           806
# 1         2     263       -46.6259      -23.4974          2           721
# 2         3     263       -46.6259      -23.4974          2           481
# 3         4     263       -46.6259      -23.4974          2           501
# 4         5     263       -46.6259      -23.4974          2           591
#
#    job_salary_max  job_salary_min  job_salary  candidate_longitude  \
# 0            1100            1100         NaN             -46.6562
# 1            1100            1100         NaN             -46.6612
# 2            1100            1100         NaN             -46.6835
# 3            1100            1100         NaN             -46.6170
# 4            1100            1100         NaN             -46.5333
#
#           ...           candidate_date_of_birth  candidate_salary  \
# ...
